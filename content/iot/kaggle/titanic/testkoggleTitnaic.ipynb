# %% [markdown]
# # 1.Input, print and numbers

# %%
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

train = pd.read_csv("Titanic/train.csv")
test = pd.read_csv("Titanic/test.csv")
submit = pd.read_csv("Titanic/gender_submission.csv")

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data = pd.concat([train, test])

# %%
data.reset_index(inplace=True,drop=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %%
sns.countplot(x=data['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x=data['Pclass'],hue=data['Survived'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x=data['Sex'],hue=data['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x=data['Embarked'],hue=data['Survived'])
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
g=sns.FacetGrid(data,col='Survived')
g.map(sns.histplot,'Age',kde=False)

# %%
g=sns.FacetGrid(data,col='Survived')
g.map(sns.histplot,'Fare',kde=False)

# %%
g=sns.FacetGrid(data,col='Survived')
g.map(sns.histplot,'SibSp',kde=False)

# %%
g=sns.FacetGrid(data,col='Survived')
g.map(sns.histplot,'Parch',kde=False)

# %%
data['Family_Size'] = data['Parch']+data['SibSp']

# %%
g=sns.FacetGrid(data,col='Survived')
g.map(sns.histplot,'Family_Size',kde=False)

# %%
data['Title1'] = data['Name'].str.split(", ", expand=True)[1]

# %%
data['Name'].str.split(", ", expand=True).head(3)
# Out:
#            0                                           1
# 0     Braund                             Mr. Owen Harris
# 1    Cumings  Mrs. John Bradley (Florence Briggs Thayer)
# 2  Heikkinen                                 Miss. Laina

# %%
data['Title1'].head(3)
# Out:
# 0                               Mr. Owen Harris
# 1    Mrs. John Bradley (Florence Briggs Thayer)
# 2                                   Miss. Laina
# Name: Title1, dtype: object

# %%
data['Title1'] = data['Title1'].str.split(".", expand=True)[0]

# %%
data['Title1'].head(3)
# Out:
# 0      Mr
# 1     Mrs
# 2    Miss
# Name: Title1, dtype: object

# %%
data['Title1'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'the Countess',
#        'Jonkheer', 'Dona'], dtype=object)

# %%
pd.crosstab(data['Title1'],data['Sex']).T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_6316a_row0_col0, #T_6316a_row0_col1, #T_6316a_row0_col2, #T_6316a_row0_col4, #T_6316a_row0_col5, #T_6316a_row0_col7, #T_6316a_row0_col8, #T_6316a_row0_col12, #T_6316a_row0_col15, #T_6316a_row0_col16, #T_6316a_row1_col3, #T_6316a_row1_col6, #T_6316a_row1_col9, #T_6316a_row1_col10, #T_6316a_row1_col11, #T_6316a_row1_col13, #T_6316a_row1_col14, #T_6316a_row1_col17 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_6316a_row0_col3, #T_6316a_row0_col6, #T_6316a_row0_col9, #T_6316a_row0_col10, #T_6316a_row0_col11, #T_6316a_row0_col13, #T_6316a_row0_col14, #T_6316a_row0_col17, #T_6316a_row1_col0, #T_6316a_row1_col1, #T_6316a_row1_col2, #T_6316a_row1_col4, #T_6316a_row1_col5, #T_6316a_row1_col7, #T_6316a_row1_col8, #T_6316a_row1_col12, #T_6316a_row1_col15, #T_6316a_row1_col16 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6316a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Title1</th>
#       <th id="T_6316a_level0_col0" class="col_heading level0 col0" >Capt</th>
#       <th id="T_6316a_level0_col1" class="col_heading level0 col1" >Col</th>
#       <th id="T_6316a_level0_col2" class="col_heading level0 col2" >Don</th>
#       <th id="T_6316a_level0_col3" class="col_heading level0 col3" >Dona</th>
#       <th id="T_6316a_level0_col4" class="col_heading level0 col4" >Dr</th>
#       <th id="T_6316a_level0_col5" class="col_heading level0 col5" >Jonkheer</th>
#       <th id="T_6316a_level0_col6" class="col_heading level0 col6" >Lady</th>
#       <th id="T_6316a_level0_col7" class="col_heading level0 col7" >Major</th>
#       <th id="T_6316a_level0_col8" class="col_heading level0 col8" >Master</th>
#       <th id="T_6316a_level0_col9" class="col_heading level0 col9" >Miss</th>
#       <th id="T_6316a_level0_col10" class="col_heading level0 col10" >Mlle</th>
#       <th id="T_6316a_level0_col11" class="col_heading level0 col11" >Mme</th>
#       <th id="T_6316a_level0_col12" class="col_heading level0 col12" >Mr</th>
#       <th id="T_6316a_level0_col13" class="col_heading level0 col13" >Mrs</th>
#       <th id="T_6316a_level0_col14" class="col_heading level0 col14" >Ms</th>
#       <th id="T_6316a_level0_col15" class="col_heading level0 col15" >Rev</th>
#       <th id="T_6316a_level0_col16" class="col_heading level0 col16" >Sir</th>
#       <th id="T_6316a_level0_col17" class="col_heading level0 col17" >the Countess</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6316a_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_6316a_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_6316a_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_6316a_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_6316a_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_6316a_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_6316a_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_6316a_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_6316a_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_6316a_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_6316a_row0_col9" class="data row0 col9" >260</td>
#       <td id="T_6316a_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_6316a_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_6316a_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_6316a_row0_col13" class="data row0 col13" >197</td>
#       <td id="T_6316a_row0_col14" class="data row0 col14" >2</td>
#       <td id="T_6316a_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_6316a_row0_col16" class="data row0 col16" >0</td>
#       <td id="T_6316a_row0_col17" class="data row0 col17" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6316a_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_6316a_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_6316a_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_6316a_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_6316a_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_6316a_row1_col4" class="data row1 col4" >7</td>
#       <td id="T_6316a_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_6316a_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_6316a_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_6316a_row1_col8" class="data row1 col8" >61</td>
#       <td id="T_6316a_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_6316a_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_6316a_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_6316a_row1_col12" class="data row1 col12" >757</td>
#       <td id="T_6316a_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_6316a_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_6316a_row1_col15" class="data row1 col15" >8</td>
#       <td id="T_6316a_row1_col16" class="data row1 col16" >1</td>
#       <td id="T_6316a_row1_col17" class="data row1 col17" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab(data['Title1'],data['Survived']).T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_c264b_row0_col0, #T_c264b_row0_col2, #T_c264b_row0_col3, #T_c264b_row0_col4, #T_c264b_row0_col11, #T_c264b_row0_col14, #T_c264b_row1_col5, #T_c264b_row1_col7, #T_c264b_row1_col8, #T_c264b_row1_col9, #T_c264b_row1_col10, #T_c264b_row1_col12, #T_c264b_row1_col13, #T_c264b_row1_col15, #T_c264b_row1_col16 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_c264b_row0_col1, #T_c264b_row0_col5, #T_c264b_row0_col6, #T_c264b_row0_col7, #T_c264b_row0_col8, #T_c264b_row0_col9, #T_c264b_row0_col10, #T_c264b_row0_col12, #T_c264b_row0_col13, #T_c264b_row0_col15, #T_c264b_row0_col16, #T_c264b_row1_col0, #T_c264b_row1_col1, #T_c264b_row1_col2, #T_c264b_row1_col3, #T_c264b_row1_col4, #T_c264b_row1_col6, #T_c264b_row1_col11, #T_c264b_row1_col14 {
#   background-color: #ffff66;
#   color: #000000;
# }
# </style>
# <table id="T_c264b">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Title1</th>
#       <th id="T_c264b_level0_col0" class="col_heading level0 col0" >Capt</th>
#       <th id="T_c264b_level0_col1" class="col_heading level0 col1" >Col</th>
#       <th id="T_c264b_level0_col2" class="col_heading level0 col2" >Don</th>
#       <th id="T_c264b_level0_col3" class="col_heading level0 col3" >Dr</th>
#       <th id="T_c264b_level0_col4" class="col_heading level0 col4" >Jonkheer</th>
#       <th id="T_c264b_level0_col5" class="col_heading level0 col5" >Lady</th>
#       <th id="T_c264b_level0_col6" class="col_heading level0 col6" >Major</th>
#       <th id="T_c264b_level0_col7" class="col_heading level0 col7" >Master</th>
#       <th id="T_c264b_level0_col8" class="col_heading level0 col8" >Miss</th>
#       <th id="T_c264b_level0_col9" class="col_heading level0 col9" >Mlle</th>
#       <th id="T_c264b_level0_col10" class="col_heading level0 col10" >Mme</th>
#       <th id="T_c264b_level0_col11" class="col_heading level0 col11" >Mr</th>
#       <th id="T_c264b_level0_col12" class="col_heading level0 col12" >Mrs</th>
#       <th id="T_c264b_level0_col13" class="col_heading level0 col13" >Ms</th>
#       <th id="T_c264b_level0_col14" class="col_heading level0 col14" >Rev</th>
#       <th id="T_c264b_level0_col15" class="col_heading level0 col15" >Sir</th>
#       <th id="T_c264b_level0_col16" class="col_heading level0 col16" >the Countess</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c264b_level0_row0" class="row_heading level0 row0" >0.000000</th>
#       <td id="T_c264b_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_c264b_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_c264b_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_c264b_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_c264b_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_c264b_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_c264b_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_c264b_row0_col7" class="data row0 col7" >17</td>
#       <td id="T_c264b_row0_col8" class="data row0 col8" >55</td>
#       <td id="T_c264b_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_c264b_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_c264b_row0_col11" class="data row0 col11" >436</td>
#       <td id="T_c264b_row0_col12" class="data row0 col12" >26</td>
#       <td id="T_c264b_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_c264b_row0_col14" class="data row0 col14" >6</td>
#       <td id="T_c264b_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_c264b_row0_col16" class="data row0 col16" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c264b_level0_row1" class="row_heading level0 row1" >1.000000</th>
#       <td id="T_c264b_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_c264b_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_c264b_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_c264b_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_c264b_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_c264b_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_c264b_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_c264b_row1_col7" class="data row1 col7" >23</td>
#       <td id="T_c264b_row1_col8" class="data row1 col8" >127</td>
#       <td id="T_c264b_row1_col9" class="data row1 col9" >2</td>
#       <td id="T_c264b_row1_col10" class="data row1 col10" >1</td>
#       <td id="T_c264b_row1_col11" class="data row1 col11" >81</td>
#       <td id="T_c264b_row1_col12" class="data row1 col12" >99</td>
#       <td id="T_c264b_row1_col13" class="data row1 col13" >1</td>
#       <td id="T_c264b_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_c264b_row1_col15" class="data row1 col15" >1</td>
#       <td id="T_c264b_row1_col16" class="data row1 col16" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.groupby(['Title1'])['Age'].mean()
# Out:
# Title1
# Capt            70.000000
# Col             54.000000
# Don             40.000000
# Dona            39.000000
# Dr              43.571429
# Jonkheer        38.000000
# Lady            48.000000
# Major           48.500000
# Master           5.482642
# Miss            21.774238
# Mlle            24.000000
# Mme             24.000000
# Mr              32.252151
# Mrs             36.994118
# Ms              28.000000
# Rev             41.250000
# Sir             49.000000
# the Countess    33.000000
# Name: Age, dtype: float64

# %%
data.groupby(['Title1','Pclass'])['Age'].mean()
# Out:
# Title1        Pclass
# Capt          1         70.000000
# Col           1         54.000000
# Don           1         40.000000
# Dona          1         39.000000
# Dr            1         45.600000
#               2         38.500000
# Jonkheer      1         38.000000
# Lady          1         48.000000
# Major         1         48.500000
# Master        1          6.984000
#               2          2.757273
#               3          6.090000
# Miss          1         30.338983
#               2         20.717083
#               3         17.360874
# Mlle          1         24.000000
# Mme           1         24.000000
# Mr            1         41.450758
#               2         32.346715
#               3         28.318910
# Mrs           1         43.208955
#               2         33.518519
#               3         32.326531
# Ms            2         28.000000
#               3               NaN
# Rev           2         41.250000
# Sir           1         49.000000
# the Countess  1         33.000000
# Name: Age, dtype: float64

# %%
data['Title2'] = data['Title1'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','the Countess','Jonkheer','Col','Rev','Capt','Sir','Don','Dona'],
         ['Miss','Mrs','Miss','Mr','Mr','Mrs','Mrs','Mr','Mr','Mr','Mr','Mr','Mr','Mrs'])

# %%
data['Title2'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master'], dtype=object)

# %%
data.groupby('Title2')['Age'].mean()
# Out:
# Title2
# Master     5.482642
# Miss      21.824366
# Mr        32.811056
# Mrs       36.971264
# Name: Age, dtype: float64

# %%
data.groupby(['Title2'])['Age'].mean()
# Out:
# Title2
# Master     5.482642
# Miss      21.824366
# Mr        32.811056
# Mrs       36.971264
# Name: Age, dtype: float64

# %%
data.groupby(['Title2','Pclass'])['Age'].mean()
# Out:
# Title2  Pclass
# Master  1          6.984000
#         2          2.757273
#         3          6.090000
# Miss    1         30.131148
#         2         20.865714
#         3         17.360874
# Mr      1         42.241497
#         2         32.914966
#         3         28.318910
# Mrs     1         42.802817
#         2         33.518519
#         3         32.326531
# Name: Age, dtype: float64

# %%
pd.crosstab(data['Title2'],data['Sex']).T.style.background_gradient(cmap='summer_r') #Checking the Initials with the Sex
# Out:
# <style type="text/css">
# #T_36aed_row0_col0, #T_36aed_row0_col2, #T_36aed_row1_col1, #T_36aed_row1_col3 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_36aed_row0_col1, #T_36aed_row0_col3, #T_36aed_row1_col0, #T_36aed_row1_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_36aed">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Title2</th>
#       <th id="T_36aed_level0_col0" class="col_heading level0 col0" >Master</th>
#       <th id="T_36aed_level0_col1" class="col_heading level0 col1" >Miss</th>
#       <th id="T_36aed_level0_col2" class="col_heading level0 col2" >Mr</th>
#       <th id="T_36aed_level0_col3" class="col_heading level0 col3" >Mrs</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36aed_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_36aed_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_36aed_row0_col1" class="data row0 col1" >264</td>
#       <td id="T_36aed_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_36aed_row0_col3" class="data row0 col3" >201</td>
#     </tr>
#     <tr>
#       <th id="T_36aed_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_36aed_row1_col0" class="data row1 col0" >61</td>
#       <td id="T_36aed_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_36aed_row1_col2" class="data row1 col2" >782</td>
#       <td id="T_36aed_row1_col3" class="data row1 col3" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab(data['Title2'],data['Survived']).T.style.background_gradient(cmap='summer_r') #Checking the Initials with t
# Out:
# <style type="text/css">
# #T_2acf0_row0_col0, #T_2acf0_row0_col1, #T_2acf0_row0_col3, #T_2acf0_row1_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_2acf0_row0_col2, #T_2acf0_row1_col0, #T_2acf0_row1_col1, #T_2acf0_row1_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2acf0">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Title2</th>
#       <th id="T_2acf0_level0_col0" class="col_heading level0 col0" >Master</th>
#       <th id="T_2acf0_level0_col1" class="col_heading level0 col1" >Miss</th>
#       <th id="T_2acf0_level0_col2" class="col_heading level0 col2" >Mr</th>
#       <th id="T_2acf0_level0_col3" class="col_heading level0 col3" >Mrs</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2acf0_level0_row0" class="row_heading level0 row0" >0.000000</th>
#       <td id="T_2acf0_row0_col0" class="data row0 col0" >17</td>
#       <td id="T_2acf0_row0_col1" class="data row0 col1" >55</td>
#       <td id="T_2acf0_row0_col2" class="data row0 col2" >451</td>
#       <td id="T_2acf0_row0_col3" class="data row0 col3" >26</td>
#     </tr>
#     <tr>
#       <th id="T_2acf0_level0_row1" class="row_heading level0 row1" >1.000000</th>
#       <td id="T_2acf0_row1_col0" class="data row1 col0" >23</td>
#       <td id="T_2acf0_row1_col1" class="data row1 col1" >130</td>
#       <td id="T_2acf0_row1_col2" class="data row1 col2" >87</td>
#       <td id="T_2acf0_row1_col3" class="data row1 col3" >102</td>
#     </tr>
#   </tbody>
# </table>

# %%
list(data.groupby(['Title2','Pclass'])['Age'].mean().items())[:3]
# Out:
# [(('Master', 1), 6.984),
#  (('Master', 2), 2.7572727272727273),
#  (('Master', 3), 6.090000000000001)]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
#  12  Family_Size  1309 non-null   int64
#  13  Title1       1309 non-null   object
#  14  Title2       1309 non-null   object
# dtypes: float64(3), int64(5), object(7)
# memory usage: 153.5+ KB

# %%
data['Ticket_info'] = data['Ticket'].apply(lambda x : x.replace(".","").replace("/","").strip().split(' ')[0] if not x.isdigit() else 'X')

# %%
data['Ticket_info'].unique()
# Out:
# array(['A5', 'PC', 'STONO2', 'X', 'PP', 'CA', 'SCParis', 'SCA4', 'A4',
#        'SP', 'SOC', 'WC', 'SOTONOQ', 'WEP', 'STONO', 'C', 'SCPARIS',
#        'SOP', 'Fa', 'LINE', 'FCC', 'SWPP', 'SCOW', 'PPP', 'SC', 'SCAH',
#        'AS', 'SOPP', 'FC', 'SOTONO2', 'CASOTON', 'SCA3', 'STONOQ', 'AQ4',
#        'A', 'LP', 'AQ3'], dtype=object)

# %%
sns.countplot(x=data['Ticket_info'], hue=data['Survived'])
# Out:
# <Axes: xlabel='Ticket_info', ylabel='count'>

# %%
data['Embarked'] = data['Embarked'].fillna('S')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1309 non-null   object
#  12  Family_Size  1309 non-null   int64
#  13  Title1       1309 non-null   object
#  14  Title2       1309 non-null   object
#  15  Ticket_info  1309 non-null   object
# dtypes: float64(3), int64(5), object(8)
# memory usage: 163.8+ KB

# %%
data['Fare'] = data['Fare'].fillna(data['Fare'].mean())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1309 non-null   object
#  12  Family_Size  1309 non-null   int64
#  13  Title1       1309 non-null   object
#  14  Title2       1309 non-null   object
#  15  Ticket_info  1309 non-null   object
# dtypes: float64(3), int64(5), object(8)
# memory usage: 163.8+ KB

# %%
data['Cabin'].head(10)
# Out:
# 0     NaN
# 1     C85
# 2     NaN
# 3    C123
# 4     NaN
# 5     NaN
# 6     E46
# 7     NaN
# 8     NaN
# 9     NaN
# Name: Cabin, dtype: object

# %%
data["Cabin"] = data['Cabin'].apply(lambda x : str(x)[0] if not pd.isnull(x) else 'NoCabin')

# %%
data["Cabin"].unique()
# Out:
# array(['NoCabin', 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %%
sns.countplot(x=data['Cabin'], hue=data['Survived'])
# Out:
# <Axes: xlabel='Cabin', ylabel='count'>

# %%
data['Sex'] = data['Sex'].astype('category').cat.codes
data['Embarked'] = data['Embarked'].astype('category').cat.codes
data['Pclass'] = data['Pclass'].astype('category').cat.codes
data['Title1'] = data['Title1'].astype('category').cat.codes
data['Title2'] = data['Title2'].astype('category').cat.codes
data['Cabin'] = data['Cabin'].astype('category').cat.codes
data['Ticket_info'] = data['Ticket_info'].astype('category').cat.codes

# %%
# dataAgeNull = data[data["Age"].isnull()]
# dataAgeNotNull = data[data["Age"].notnull()]
# remove_outlier = dataAgeNotNull[(np.abs(dataAgeNotNull["Fare"]-dataAgeNotNull["Fare"].mean())>(4*dataAgeNotNull["Fare"].std()))|
#                       (np.abs(dataAgeNotNull["Family_Size"]-dataAgeNotNull["Family_Size"].mean())>(4*dataAgeNotNull["Family_Size"].std()))                     
#                      ]
# rfModel_age = RandomForestRegressor(n_estimators=2000,random_state=42)
# ageColumns = ['Embarked', 'Fare', 'Pclass', 'Sex', 'Family_Size', 'Title1', 'Title2','Cabin','Ticket_info']
# rfModel_age.fit(remove_outlier[ageColumns], remove_outlier["Age"])

# ageNullValues = rfModel_age.predict(X= dataAgeNull[ageColumns])
# dataAgeNull.loc[:,"Age"] = ageNullValues
# data = dataAgeNull.append(dataAgeNotNull)
# data.reset_index(inplace=True, drop=True)

# %%
dataAgeNull = data[data["Age"].isnull()]

# %%
dataAgeNotNull = data[data["Age"].notnull()]

# %%
remove_outlier = dataAgeNotNull[(np.abs(dataAgeNotNull["Fare"]-dataAgeNotNull["Fare"].mean())>(4*dataAgeNotNull["Fare"].std()))|
                      (np.abs(dataAgeNotNull["Family_Size"]-dataAgeNotNull["Family_Size"].mean())>(4*dataAgeNotNull["Family_Size"].std()))                     
                     ]

# %%
rfModel_age = RandomForestRegressor(n_estimators=2000,random_state=42)

# %%
ageColumns = ['Embarked', 'Fare', 'Pclass', 'Sex', 'Family_Size', 'Title1', 'Title2','Cabin','Ticket_info']

# %%
rfModel_age.fit(remove_outlier[ageColumns], remove_outlier["Age"])
# Out:
# RandomForestRegressor(n_estimators=2000, random_state=42)

# %%
ageNullValues = rfModel_age.predict(X= dataAgeNull[ageColumns])

# %%
# dataAgeNull.loc[:,"Age"] = ageNullValues

# %%
dataAgeNull.loc[:]["Age"] = ageNullValues

# %%
data = pd.concat([dataAgeNull,dataAgeNotNull])

# %%
data.reset_index(inplace=True, drop=True)

# %%
dataAgeNull
# Out:
#       PassengerId  Survived  Pclass                             Name  Sex  \
# 5               6       0.0       2                 Moran, Mr. James    1
# 17             18       1.0       1     Williams, Mr. Charles Eugene    1
# 19             20       1.0       2          Masselmani, Mrs. Fatima    0
# 26             27       0.0       2          Emir, Mr. Farred Chehab    1
# 28             29       1.0       2    O'Dwyer, Miss. Ellen "Nellie"    0
# ...           ...       ...     ...                              ...  ...
# 1299         1300       NaN       2  Riordan, Miss. Johanna Hannah""    0
# 1301         1302       NaN       2           Naughton, Miss. Hannah    0
# 1304         1305       NaN       2               Spector, Mr. Woolf    1
# 1307         1308       NaN       2              Ware, Mr. Frederick    1
# 1308         1309       NaN       2         Peter, Master. Michael J    1
#
#       Age  SibSp  Parch     Ticket     Fare  Cabin  Embarked  Family_Size  \
# 5     NaN      0      0     330877   8.4583      7         1            0
# 17    NaN      0      0     244373  13.0000      7         2            0
# 19    NaN      0      0       2649   7.2250      7         0            0
# 26    NaN      0      0       2631   7.2250      7         0            0
# 28    NaN      0      0     330959   7.8792      7         1            0
# ...   ...    ...    ...        ...      ...    ...       ...          ...
# 1299  NaN      0      0     334915   7.7208      7         1            0
# 1301  NaN      0      0     365237   7.7500      7         1            0
# 1304  NaN      0      0  A.5. 3236   8.0500      7         2            0
# 1307  NaN      0      0     359309   8.0500      7         2            0
# 1308  NaN      1      1       2668  22.3583      7         0            2
#
#       Title1  Title2  Ticket_info
# 5         12       2           36
# 17        12       2           36
# 19        13       3           36
# 26        12       2           36
# 28         9       1           36
# ...      ...     ...          ...
# 1299       9       1           36
# 1301       9       1           36
# 1304      12       2            2
# 1307      12       2           36
# 1308       8       0           36
#
# [263 rows x 16 columns]

# %%
dataAgeNotNull
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       2
# 1               2       1.0       0
# 2               3       1.0       2
# 3               4       1.0       0
# 4               5       0.0       2
# ...           ...       ...     ...
# 1300         1301       NaN       2
# 1302         1303       NaN       0
# 1303         1304       NaN       2
# 1305         1306       NaN       0
# 1306         1307       NaN       2
#
#                                                    Name  Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    1  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                                Heikkinen, Miss. Laina    0  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                              Allen, Mr. William Henry    1  35.0      0
# ...                                                 ...  ...   ...    ...
# 1300                          Peacock, Miss. Treasteall    0   3.0      1
# 1302    Minahan, Mrs. William Edward (Lillian E Thorpe)    0  37.0      1
# 1303                     Henriksson, Miss. Jenny Lovisa    0  28.0      0
# 1305                       Oliva y Ocana, Dona. Fermina    0  39.0      0
# 1306                       Saether, Mr. Simon Sivertsen    1  38.5      0
#
#       Parch              Ticket      Fare  Cabin  Embarked  Family_Size  \
# 0         0           A/5 21171    7.2500      7         2            1
# 1         0            PC 17599   71.2833      2         0            1
# 2         0    STON/O2. 3101282    7.9250      7         2            0
# 3         0              113803   53.1000      2         2            1
# 4         0              373450    8.0500      7         2            0
# ...     ...                 ...       ...    ...       ...          ...
# 1300      1  SOTON/O.Q. 3101315   13.7750      7         2            2
# 1302      0               19928   90.0000      2         1            1
# 1303      0              347086    7.7750      7         2            0
# 1305      0            PC 17758  108.9000      2         0            0
# 1306      0  SOTON/O.Q. 3101262    7.2500      7         2            0
#
#       Title1  Title2  Ticket_info
# 0         12       2            2
# 1         13       3           14
# 2          9       1           31
# 3         13       3           36
# 4         12       2           36
# ...      ...     ...          ...
# 1300       9       1           28
# 1302      13       3           36
# 1303       9       1           36
# 1305       3       3           14
# 1306      12       2           28
#
# [1046 rows x 16 columns]

# %%
data
# Out:
#       PassengerId  Survived  Pclass  \
# 0               6       0.0       2
# 1              18       1.0       1
# 2              20       1.0       2
# 3              27       0.0       2
# 4              29       1.0       2
# ...           ...       ...     ...
# 1304         1301       NaN       2
# 1305         1303       NaN       0
# 1306         1304       NaN       2
# 1307         1306       NaN       0
# 1308         1307       NaN       2
#
#                                                  Name  Sex   Age  SibSp  \
# 0                                    Moran, Mr. James    1   NaN      0
# 1                        Williams, Mr. Charles Eugene    1   NaN      0
# 2                             Masselmani, Mrs. Fatima    0   NaN      0
# 3                             Emir, Mr. Farred Chehab    1   NaN      0
# 4                       O'Dwyer, Miss. Ellen "Nellie"    0   NaN      0
# ...                                               ...  ...   ...    ...
# 1304                        Peacock, Miss. Treasteall    0   3.0      1
# 1305  Minahan, Mrs. William Edward (Lillian E Thorpe)    0  37.0      1
# 1306                   Henriksson, Miss. Jenny Lovisa    0  28.0      0
# 1307                     Oliva y Ocana, Dona. Fermina    0  39.0      0
# 1308                     Saether, Mr. Simon Sivertsen    1  38.5      0
#
#       Parch              Ticket      Fare  Cabin  Embarked  Family_Size  \
# 0         0              330877    8.4583      7         1            0
# 1         0              244373   13.0000      7         2            0
# 2         0                2649    7.2250      7         0            0
# 3         0                2631    7.2250      7         0            0
# 4         0              330959    7.8792      7         1            0
# ...     ...                 ...       ...    ...       ...          ...
# 1304      1  SOTON/O.Q. 3101315   13.7750      7         2            2
# 1305      0               19928   90.0000      2         1            1
# 1306      0              347086    7.7750      7         2            0
# 1307      0            PC 17758  108.9000      2         0            0
# 1308      0  SOTON/O.Q. 3101262    7.2500      7         2            0
#
#       Title1  Title2  Ticket_info
# 0         12       2           36
# 1         12       2           36
# 2         13       3           36
# 3         12       2           36
# 4          9       1           36
# ...      ...     ...          ...
# 1304       9       1           28
# 1305      13       3           36
# 1306       9       1           36
# 1307       3       3           14
# 1308      12       2           28
#
# [1309 rows x 16 columns]

# %%
remove_outlier = dataAgeNotNull[(np.abs(dataAgeNotNull["Fare"]-dataAgeNotNull["Fare"].mean())>(4*dataAgeNotNull["Fare"].std()))|
                      (np.abs(dataAgeNotNull["Family_Size"]-dataAgeNotNull["Family_Size"].mean())>(4*dataAgeNotNull["Family_Size"].std()))                     
                     ]

# %%
rfModel_age = RandomForestRegressor(n_estimators=2000,random_state=42)

# %%
ageColumns = ['Embarked', 'Fare', 'Pclass', 'Sex', 'Family_Size', 'Title1', 'Title2','Cabin','Ticket_info']

# %%
rfModel_age.fit(remove_outlier[ageColumns], remove_outlier["Age"])
# Out:
# RandomForestRegressor(n_estimators=2000, random_state=42)

# %%
ageNullValues = rfModel_age.predict(X= dataAgeNull[ageColumns])

# %%
# ageNullValues

# %%
# dataAgeNull.loc[:,"Age"] = ageNullValues

# %%
# dataAgeNull.loc[1:50,"Age"]

# %%
dataAgeNotNull
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       2
# 1               2       1.0       0
# 2               3       1.0       2
# 3               4       1.0       0
# 4               5       0.0       2
# ...           ...       ...     ...
# 1300         1301       NaN       2
# 1302         1303       NaN       0
# 1303         1304       NaN       2
# 1305         1306       NaN       0
# 1306         1307       NaN       2
#
#                                                    Name  Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    1  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                                Heikkinen, Miss. Laina    0  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                              Allen, Mr. William Henry    1  35.0      0
# ...                                                 ...  ...   ...    ...
# 1300                          Peacock, Miss. Treasteall    0   3.0      1
# 1302    Minahan, Mrs. William Edward (Lillian E Thorpe)    0  37.0      1
# 1303                     Henriksson, Miss. Jenny Lovisa    0  28.0      0
# 1305                       Oliva y Ocana, Dona. Fermina    0  39.0      0
# 1306                       Saether, Mr. Simon Sivertsen    1  38.5      0
#
#       Parch              Ticket      Fare  Cabin  Embarked  Family_Size  \
# 0         0           A/5 21171    7.2500      7         2            1
# 1         0            PC 17599   71.2833      2         0            1
# 2         0    STON/O2. 3101282    7.9250      7         2            0
# 3         0              113803   53.1000      2         2            1
# 4         0              373450    8.0500      7         2            0
# ...     ...                 ...       ...    ...       ...          ...
# 1300      1  SOTON/O.Q. 3101315   13.7750      7         2            2
# 1302      0               19928   90.0000      2         1            1
# 1303      0              347086    7.7750      7         2            0
# 1305      0            PC 17758  108.9000      2         0            0
# 1306      0  SOTON/O.Q. 3101262    7.2500      7         2            0
#
#       Title1  Title2  Ticket_info
# 0         12       2            2
# 1         13       3           14
# 2          9       1           31
# 3         13       3           36
# 4         12       2           36
# ...      ...     ...          ...
# 1300       9       1           28
# 1302      13       3           36
# 1303       9       1           36
# 1305       3       3           14
# 1306      12       2           28
#
# [1046 rows x 16 columns]

# %%
data.reset_index(inplace=True, drop=True)

# %%
dataAgeNull.loc[:,"Age"] = ageNullValues
# Out:
# C:\Users\no14\AppData\Local\Temp\ipykernel_4524\1308218851.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataAgeNull.loc[:,"Age"] = ageNullValues

# %%
dataAgeNull
# Out:
#       PassengerId  Survived  Pclass                             Name  Sex  \
# 5               6       0.0       2                 Moran, Mr. James    1
# 17             18       1.0       1     Williams, Mr. Charles Eugene    1
# 19             20       1.0       2          Masselmani, Mrs. Fatima    0
# 26             27       0.0       2          Emir, Mr. Farred Chehab    1
# 28             29       1.0       2    O'Dwyer, Miss. Ellen "Nellie"    0
# ...           ...       ...     ...                              ...  ...
# 1299         1300       NaN       2  Riordan, Miss. Johanna Hannah""    0
# 1301         1302       NaN       2           Naughton, Miss. Hannah    0
# 1304         1305       NaN       2               Spector, Mr. Woolf    1
# 1307         1308       NaN       2              Ware, Mr. Frederick    1
# 1308         1309       NaN       2         Peter, Master. Michael J    1
#
#             Age  SibSp  Parch     Ticket     Fare  Cabin  Embarked  \
# 5     41.326267      0      0     330877   8.4583      7         1
# 17    41.616486      0      0     244373  13.0000      7         2
# 19    46.792625      0      0       2649   7.2250      7         0
# 26    41.326267      0      0       2631   7.2250      7         0
# 28    34.860886      0      0     330959   7.8792      7         1
# ...         ...    ...    ...        ...      ...    ...       ...
# 1299  34.860886      0      0     334915   7.7208      7         1
# 1301  34.860886      0      0     365237   7.7500      7         1
# 1304  34.382350      0      0  A.5. 3236   8.0500      7         2
# 1307  39.428653      0      0     359309   8.0500      7         2
# 1308  26.750358      1      1       2668  22.3583      7         0
#
#       Family_Size  Title1  Title2  Ticket_info
# 5               0      12       2           36
# 17              0      12       2           36
# 19              0      13       3           36
# 26              0      12       2           36
# 28              0       9       1           36
# ...           ...     ...     ...          ...
# 1299            0       9       1           36
# 1301            0       9       1           36
# 1304            0      12       2            2
# 1307            0      12       2           36
# 1308            2       8       0           36
#
# [263 rows x 16 columns]

# %%
ageNullValues[1]
# Out:
# 41.616486111111115

# %%
ageNullValues
# Out:
# array([41.32626667, 41.61648611, 46.792625  , 41.32626667, 34.86088571,
#        39.42865278, 49.28626667, 34.86088571, 41.32626667, 41.32626667,
#        36.905825  , 42.61876667, 34.86088571, 42.61876667, 42.08580278,
#        41.28170833, 26.75035833, 39.42865278, 39.42865278, 34.86088571,
#        39.42865278, 39.42865278, 39.42865278, 39.42865278, 34.92738571,
#        34.38235   , 41.32626667, 34.92738571, 48.067375  , 36.905825  ,
#        39.42865278, 11.94185992, 50.39128333, 39.26073333, 11.77477302,
#        15.47041071, 41.2727    , 42.56413611, 48.067375  , 41.32626667,
#        34.86088571, 28.43759762, 42.61876667, 39.42865278, 19.03415873,
#        33.55016766, 34.92738571, 34.92738571, 39.42865278, 46.33575833,
#        41.32626667, 34.86088571, 41.61648611, 34.86088571, 41.61648611,
#        42.56413611, 41.28170833, 42.08580278, 34.86088571, 42.61876667,
#        33.31380238, 34.38235   , 37.06933571, 28.43759762, 34.92738571,
#        47.44696667, 39.42865278, 47.50355   , 42.08580278, 41.32626667,
#        34.86088571, 34.86088571, 42.61876667, 46.792625  , 34.86088571,
#        48.07000833, 39.42865278, 41.32626667, 19.03415873, 39.42865278,
#        41.32626667, 41.61648611, 46.4063    , 41.32626667, 34.38235   ,
#        41.32626667, 47.50355   , 39.42865278, 40.57190278, 34.38235   ,
#        50.39128333, 41.32626667, 34.38235   , 41.61648611, 41.32626667,
#        39.42865278, 42.56413611, 41.61648611, 19.03415873, 40.57190278,
#        41.32626667, 34.38235   , 34.86088571, 41.61648611, 39.42865278,
#        41.32626667, 41.32626667, 41.32626667, 42.241975  , 41.32626667,
#        48.067375  , 39.42865278, 41.2727    , 41.32626667, 43.79620833,
#        41.32626667, 39.42865278, 33.55016766, 41.32626667, 34.86088571,
#        48.067375  , 41.32626667, 34.38235   , 34.92738571, 35.52074742,
#        41.32626667, 39.42865278, 41.61648611, 39.42865278, 34.92738571,
#        41.32626667, 41.32626667, 41.61648611, 40.57190278, 39.42865278,
#        39.42865278, 39.42865278, 34.86088571, 39.42865278, 39.42865278,
#        50.39128333, 41.61648611, 34.86088571, 39.42865278, 34.86088571,
#        26.75035833, 42.08580278, 41.32626667, 34.86088571, 41.61648611,
#        39.42865278, 39.42865278, 42.08580278, 39.42865278, 36.45080357,
#        42.61876667, 41.32626667, 41.32626667, 41.32626667, 39.61292123,
#        41.32626667, 15.47041071, 41.28170833, 42.56413611, 41.32626667,
#        39.42865278, 41.32626667, 41.32626667, 39.42865278, 43.97081667,
#        28.43759762, 50.79911667, 41.32626667, 15.47041071, 39.42865278,
#        39.42865278, 19.09940873, 39.42865278, 45.92496667, 42.61876667,
#        47.10451667, 33.55016766, 39.42865278, 42.08580278, 41.32626667,
#        41.28170833, 40.57190278, 44.37198333, 39.42865278, 39.42865278,
#        43.52425   , 42.61876667, 40.36109405, 39.42865278, 39.42865278,
#        41.32626667, 41.32626667, 39.42865278, 34.86088571, 41.32626667,
#        42.61876667, 41.32626667, 34.92738571, 47.13014167, 42.61876667,
#        42.08580278, 41.61648611, 41.32626667, 34.86088571, 39.42865278,
#        48.12094167, 39.42865278, 41.32626667, 41.32626667, 15.47041071,
#        41.61648611, 46.4063    , 34.86088571, 38.82398333, 39.42865278,
#        34.86088571, 39.42865278, 48.067375  , 34.86088571, 41.32626667,
#        39.42865278, 11.81377302, 48.067375  , 34.38235   , 36.458925  ,
#        39.42865278, 41.61648611, 34.38235   , 31.78424524, 41.32626667,
#        34.92738571, 41.32626667, 34.86088571, 39.42865278, 41.32626667,
#        34.38235   , 39.26073333, 41.32626667, 42.61876667, 43.97081667,
#        34.86088571, 36.905825  , 41.32626667, 26.72635833, 28.43759762,
#        24.06724762, 39.42865278, 41.32626667, 40.60577143, 42.61876667,
#        41.32626667, 46.4063    , 39.22713611, 34.86088571, 34.86088571,
#        34.38235   , 39.42865278, 26.75035833])

# %%
dataAgeNull.loc[:]["Age"] = ageNullValues

# %%
# dataAgeNull.loc[1:5]["Age"]

# %%
dataAgeNull
# Out:
#       PassengerId  Survived  Pclass                             Name  Sex  \
# 5               6       0.0       2                 Moran, Mr. James    1
# 17             18       1.0       1     Williams, Mr. Charles Eugene    1
# 19             20       1.0       2          Masselmani, Mrs. Fatima    0
# 26             27       0.0       2          Emir, Mr. Farred Chehab    1
# 28             29       1.0       2    O'Dwyer, Miss. Ellen "Nellie"    0
# ...           ...       ...     ...                              ...  ...
# 1299         1300       NaN       2  Riordan, Miss. Johanna Hannah""    0
# 1301         1302       NaN       2           Naughton, Miss. Hannah    0
# 1304         1305       NaN       2               Spector, Mr. Woolf    1
# 1307         1308       NaN       2              Ware, Mr. Frederick    1
# 1308         1309       NaN       2         Peter, Master. Michael J    1
#
#             Age  SibSp  Parch     Ticket     Fare  Cabin  Embarked  \
# 5     41.326267      0      0     330877   8.4583      7         1
# 17    41.616486      0      0     244373  13.0000      7         2
# 19    46.792625      0      0       2649   7.2250      7         0
# 26    41.326267      0      0       2631   7.2250      7         0
# 28    34.860886      0      0     330959   7.8792      7         1
# ...         ...    ...    ...        ...      ...    ...       ...
# 1299  34.860886      0      0     334915   7.7208      7         1
# 1301  34.860886      0      0     365237   7.7500      7         1
# 1304  34.382350      0      0  A.5. 3236   8.0500      7         2
# 1307  39.428653      0      0     359309   8.0500      7         2
# 1308  26.750358      1      1       2668  22.3583      7         0
#
#       Family_Size  Title1  Title2  Ticket_info
# 5               0      12       2           36
# 17              0      12       2           36
# 19              0      13       3           36
# 26              0      12       2           36
# 28              0       9       1           36
# ...           ...     ...     ...          ...
# 1299            0       9       1           36
# 1301            0       9       1           36
# 1304            0      12       2            2
# 1307            0      12       2           36
# 1308            2       8       0           36
#
# [263 rows x 16 columns]

# %%
data = pd.concat([dataAgeNull,dataAgeNotNull])

# %%
data.reset_index(inplace=True, drop=True)

# %%
data
# Out:
#       PassengerId  Survived  Pclass  \
# 0               6       0.0       2
# 1              18       1.0       1
# 2              20       1.0       2
# 3              27       0.0       2
# 4              29       1.0       2
# ...           ...       ...     ...
# 1304         1301       NaN       2
# 1305         1303       NaN       0
# 1306         1304       NaN       2
# 1307         1306       NaN       0
# 1308         1307       NaN       2
#
#                                                  Name  Sex        Age  SibSp  \
# 0                                    Moran, Mr. James    1  41.326267      0
# 1                        Williams, Mr. Charles Eugene    1  41.616486      0
# 2                             Masselmani, Mrs. Fatima    0  46.792625      0
# 3                             Emir, Mr. Farred Chehab    1  41.326267      0
# 4                       O'Dwyer, Miss. Ellen "Nellie"    0  34.860886      0
# ...                                               ...  ...        ...    ...
# 1304                        Peacock, Miss. Treasteall    0   3.000000      1
# 1305  Minahan, Mrs. William Edward (Lillian E Thorpe)    0  37.000000      1
# 1306                   Henriksson, Miss. Jenny Lovisa    0  28.000000      0
# 1307                     Oliva y Ocana, Dona. Fermina    0  39.000000      0
# 1308                     Saether, Mr. Simon Sivertsen    1  38.500000      0
#
#       Parch              Ticket      Fare  Cabin  Embarked  Family_Size  \
# 0         0              330877    8.4583      7         1            0
# 1         0              244373   13.0000      7         2            0
# 2         0                2649    7.2250      7         0            0
# 3         0                2631    7.2250      7         0            0
# 4         0              330959    7.8792      7         1            0
# ...     ...                 ...       ...    ...       ...          ...
# 1304      1  SOTON/O.Q. 3101315   13.7750      7         2            2
# 1305      0               19928   90.0000      2         1            1
# 1306      0              347086    7.7750      7         2            0
# 1307      0            PC 17758  108.9000      2         0            0
# 1308      0  SOTON/O.Q. 3101262    7.2500      7         2            0
#
#       Title1  Title2  Ticket_info
# 0         12       2           36
# 1         12       2           36
# 2         13       3           36
# 3         12       2           36
# 4          9       1           36
# ...      ...     ...          ...
# 1304       9       1           28
# 1305      13       3           36
# 1306       9       1           36
# 1307       3       3           14
# 1308      12       2           28
#
# [1309 rows x 16 columns]

# %%
dataTrain = data[pd.notnull(data['Survived'])].sort_values(by=["PassengerId"])
dataTest = data[~pd.notnull(data['Survived'])].sort_values(by=["PassengerId"])

# %%
dataTrain.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Family_Size', 'Title1',
#        'Title2', 'Ticket_info'],
#       dtype='object')

# %%
dataTrain = dataTrain[['Survived', 'Age', 'Embarked', 'Fare',  'Pclass', 'Sex', 'Family_Size', 'Title2','Ticket_info','Cabin']]
dataTest = dataTest[['Age', 'Embarked', 'Fare', 'Pclass', 'Sex', 'Family_Size', 'Title2','Ticket_info','Cabin']]

# %%
dataTrain
# Out:
#      Survived        Age  Embarked     Fare  Pclass  Sex  Family_Size  Title2  \
# 263       0.0  22.000000         2   7.2500       2    1            1       2
# 264       1.0  38.000000         0  71.2833       0    0            1       3
# 265       1.0  26.000000         2   7.9250       2    0            0       1
# 266       1.0  35.000000         2  53.1000       0    0            1       3
# 267       0.0  35.000000         2   8.0500       2    1            0       2
# ..        ...        ...       ...      ...     ...  ...          ...     ...
# 973       0.0  27.000000         2  13.0000       1    1            0       2
# 974       1.0  19.000000         2  30.0000       0    0            0       1
# 176       0.0  19.099409         2  23.4500       2    0            3       1
# 975       1.0  26.000000         0  30.0000       0    1            0       2
# 976       0.0  32.000000         1   7.7500       2    1            0       2
#
#      Ticket_info  Cabin
# 263            2      7
# 264           14      2
# 265           31      7
# 266           36      2
# 267           36      7
# ..           ...    ...
# 973           36      7
# 974           36      1
# 176           34      7
# 975           36      2
# 976           36      7
#
# [891 rows x 10 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
 
rf = RandomForestClassifier(criterion='gini', 
                             n_estimators=1000,
                             min_samples_split=12,
                             min_samples_leaf=1,
                             oob_score=True,
                             random_state=1,
                             n_jobs=-1) 

rf.fit(dataTrain.iloc[:, 1:], dataTrain.iloc[:, 0])
print("%.4f" % rf.oob_score_)
# Out:
# 0.8294

# %%
pd.concat((pd.DataFrame(dataTrain.iloc[:, 1:].columns, columns = ['variable']), 
           pd.DataFrame(rf.feature_importances_, columns = ['importance'])), 
          axis = 1).sort_values(by='importance', ascending = False)[:20]
# Out:
#       variable  importance
# 4          Sex    0.264997
# 2         Fare    0.163890
# 6       Title2    0.152698
# 0          Age    0.131891
# 3       Pclass    0.091048
# 5  Family_Size    0.070839
# 8        Cabin    0.067029
# 7  Ticket_info    0.031735
# 1     Embarked    0.025873

# %%
rf_res =  rf.predict(dataTest)
submit['Survived'] = rf_res
submit['Survived'] = submit['Survived'].astype(int)
submit.to_csv('submit.csv', index= False)

# %%
submit
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         1
#
# [418 rows x 2 columns]
